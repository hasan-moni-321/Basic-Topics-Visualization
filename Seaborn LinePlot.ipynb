# %%
import seaborn as sns

# %%
fmri = sns.load_dataset('fmri')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.shape
# Out:
# (1064, 5)

# %%
fmri.event.unique()
# Out:
# array(['stim', 'cue'], dtype=object)

# %%
fmri.region.unique()
# Out:
# array(['parietal', 'frontal'], dtype=object)

# %%
fmri.subject.nunique()
# Out:
# 14

# %%
sns.lineplot('timepoint', 'signal', data=fmri)

# %%
sns.lineplot('timepoint','signal', hue='event', data=fmri)

# %%
sns.lineplot('timepoint','signal', hue='event', style='event', data=fmri)

# %%
sns.lineplot('timepoint','signal', hue='event', style='region', data=fmri)

# %%
sns.lineplot('timepoint','signal', hue='subject', data=fmri)

# %%
sns.lineplot('timepoint','signal', hue='event', style='event', markers=True, dashes=False, data=fmri)

# %%
sns.lineplot('timepoint','signal', hue='event', err_style='bars', ci=70,data=fmri)
